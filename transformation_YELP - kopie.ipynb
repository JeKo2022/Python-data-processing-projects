# %%
## HEALTH CODE INSPECTIONS / YELP

# Are there any words whose presence in a Yelp review 
# might indicate that there is a serious health code violation present at a restaurant?

# %%
import csv 
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import sklearn as sk
from sklearn.linear_model import LinearRegression

# %%
## LOADING THE DATA: correctly read input files into pandas DataFrames

# do not use the first column as the index, set header to first row, skip spaces after delimiter
hcvs = pd.read_csv('Health_Code_Violations_Seattle.CSV', index_col = False, header = 0, skipinitialspace = True)

# print head
hcvs.head(5)

# display(hcvs)
# Out:
# C:\Users\jeani\anaconda3\envs\progLab\lib\site-packages\IPython\core\interactiveshell.py:3441: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#                Name Program Identifier Inspection Date  \
# 0  @ THE SHACK, LLC       SHACK COFFEE      08/03/2019
# 1  @ THE SHACK, LLC       SHACK COFFEE      10/03/2018
# 2  @ THE SHACK, LLC       SHACK COFFEE      10/03/2018
# 3  @ THE SHACK, LLC       SHACK COFFEE      04/02/2018
# 4  @ THE SHACK, LLC       SHACK COFFEE      07/27/2017
#
#                         Description              Address     City Zip Code  \
# 0  Seating 0-12 - Risk Category III  2920 SW AVALON WAY   Seattle    98126
# 1  Seating 0-12 - Risk Category III  2920 SW AVALON WAY   Seattle    98126
# 2  Seating 0-12 - Risk Category III  2920 SW AVALON WAY   Seattle    98126
# 3  Seating 0-12 - Risk Category III  2920 SW AVALON WAY   Seattle    98126
# ...

# %%
# YELP DATA

# %%
# read file
buisnessdata = [json.loads(line) for line in open('business.json', 'r')]

# display(buisnessdata)
